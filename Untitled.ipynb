# %%
import great_expectations as ge
from pandas import json_normalize
import json
import pandas as pd
import flat_table

df = ge.read_json(
    "data/yelp_academic_dataset_business.json",
    lines=True
)

# %%
df2 = flat_table.normalize(df)

# %%
json_normalize(df["hours"]).shape
# Out:
# (10, 7)

# %%
df2.shape
# Out:
# (10, 45)

# %%
df3 = flat_table.normalize(df2)

# %%
df3.columns
# Out:
# Index(['level_0', 'index', 'business_id', 'name', 'address', 'city', 'state',
#        'postal_code', 'latitude', 'longitude', 'stars', 'review_count',
#        'is_open', 'categories', 'attributes.AcceptsInsurance',
#        'attributes.ByAppointmentOnly', 'attributes.GoodForKids',
#        'attributes.RestaurantsDelivery', 'attributes.RestaurantsAttire',
#        'attributes.NoiseLevel', 'attributes.RestaurantsTakeOut',
#        'attributes.DogsAllowed', 'attributes.GoodForMeal',
#        'attributes.Alcohol', 'attributes.HasTV', 'attributes.Ambience',
#        'attributes.RestaurantsPriceRange2',
#        'attributes.BusinessAcceptsBitcoin', 'attributes.HappyHour',
#        'attributes.RestaurantsGoodForGroups', 'attributes.OutdoorSeating',
#        'attributes.Caters', 'attributes.WheelchairAccessible',
#        'attributes.RestaurantsReservations',
#        'attributes.BusinessAcceptsCreditCards', 'attributes.BusinessParking',
# ...

# %%
df3.iloc[:,35:]
# Out:
#                           attributes.BusinessParking attributes.BikeParking  \
# 0  {'garage': False, 'street': True, 'validated':...                   True
# 1  {'garage': True, 'street': False, 'validated':...                  False
# 2  {'garage': False, 'street': True, 'validated':...                  False
# 3                                                NaN                    NaN
# 4  {'garage': False, 'street': False, 'validated'...                    NaN
# 5  {'garage': False, 'street': True, 'validated':...                   True
# 6                                                NaN                    NaN
# 7                                                NaN                    NaN
# 8  {'garage': False, 'street': False, 'validated'...                   True
# 9  {'garage': False, 'street': False, 'validated'...                    NaN
#
#   attributes.WiFi attributes.RestaurantsTableService hours.Sunday  \
# ...

# %%
json_normalize(df['attributes'], max_level=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15272/3642313674.py in <module>
# ----> 1 json_normalize(df['attributes'], max_level=2)
#
# c:\users\dell\desktop\darmadia\great-expectations-for-json\.venv\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     444             # TODO: handle record value which are lists, at least error
#     445             #       reasonably
# --> 446             data = nested_to_record(data, sep=sep, max_level=max_level)
#     447         return DataFrame(data)
#     448     elif not isinstance(record_path, list):
#
# c:\users\dell\desktop\darmadia\great-expectations-for-json\.venv\lib\site-packages\pandas\io\json\_normalize.py in nested_to_record(ds, prefix, sep, level, max_level)
#      90     for d in ds:
# ...

# %%
json_file = "data/yelp_academic_dataset_business.json"

# %%
with open(json_file, "r") as f:
    data = json.load(f)

# %%
json_normalize

# %%
json_normalize(data['attr', max_level=10, errors='ignore').iloc[:,10:25]
# Out:
#    is_open                                         categories  \
# 0        1  Gastropubs, Food, Beer Gardens, Restaurants, B...
# 1        1  Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 2        1  Antiques, Fashion, Used, Vintage & Consignment...
# 3        1                         Beauty & Spas, Hair Salons
# 4        1  Gyms, Active Life, Interval Training Gyms, Fit...
# 5        1                                  Restaurants, Thai
# 6        1          Dentists, Health & Medical, Orthodontists
# 7        1                    Breakfast & Brunch, Restaurants
# 8        1  Shopping, Jewelry Repair, Appraisal Services, ...
# 9        0                             Barbers, Beauty & Spas
#
#   attributes.RestaurantsTableService attributes.WiFi attributes.BikeParking  \
# 0                               True         u'free'                   True
# 1                                NaN         u'free'                  False
# ...

# %%
df.iloc[:,15:25]
# Out:
#                           attributes.BusinessParking  \
# 0  {'garage': False, 'street': True, 'validated':...
# 1  {'garage': True, 'street': False, 'validated':...
# 2  {'garage': False, 'street': True, 'validated':...
# 3                                                NaN
# 4  {'garage': False, 'street': False, 'validated'...
# 5  {'garage': False, 'street': True, 'validated':...
# 6                                                NaN
# 7                                                NaN
# 8  {'garage': False, 'street': False, 'validated'...
# 9  {'garage': False, 'street': False, 'validated'...
#
#   attributes.BusinessAcceptsCreditCards attributes.RestaurantsReservations  \
# 0                                  True                              False
# 1                                  True                              False
# 2                                  True                                NaN
# 3                                  True                                NaN
# ...

# %%
df
# Out:
#               business_id                       name  \
# 0  6iYb2HFDywm3zjuRg0shjw        Oskar Blues Taproom
# 1  tCbdrRPZA0oiIYSmHG3J0w    Flying Elephants at PDX
# 2  bvN78flM8NLprQ1a1y5dRg             The Reclaimory
# 3  oaepsyvc0J17qwi8cfrOWg                Great Clips
# 4  PE9uqAjdw0E4-8mjGl3wVA          Crossfit Terminus
# 5  D4JtQNTI4X3KcbzacDJsMw        Bob Likes Thai Food
# 6  t35jsh9YnMtttm69UCp7gw        Escott Orthodontics
# 7  jFYIsSb7r1QeESVUnXPHBw            Boxwood Biscuit
# 8  N3_Gs3DnX4k9SgpwJxdEfw  Lane Wells Jewelry Repair
# 9  tXvdYGvlEceDljN8gt2_3Q   Capital City Barber Shop
#
#                        address         city state postal_code   latitude  \
# 0                 921 Pearl St      Boulder    CO       80302  40.017544
# 1          7000 NE Airport Way     Portland    OR       97218  45.588906
# 2           4720 Hawthorne Ave     Portland    OR       97214  45.511907
# 3           2566 Enterprise Rd  Orange City    FL       32763  28.914482
# ...
